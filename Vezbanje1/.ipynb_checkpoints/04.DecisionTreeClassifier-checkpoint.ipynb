# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../datasets/data.csv')

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
data.isna().any().any()
# Out:
# True

# %%
data.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
data.shape
# Out:
# (569, 33)

# %%
data.drop('id', axis=1, inplace=True)

# %%
data.drop('Unnamed: 32', axis=1, inplace=True)

# %%
data.isna().any().any()
# Out:
# False

# %%
Y = data['diagnosis']
X = data.drop('diagnosis', axis=1)

# %%
feature_names = X.columns

# %%
edges, lines, bins = plt.hist(Y)
plt.bar_label(bins)
plt.show()

# %%
Y.replace('B', 0, inplace=True)

# %%
Y.replace('M', 1, inplace=True)

# %%
np.unique(Y)
# Out:
# array([0, 1])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=123, stratify=Y)

# %%
X_train.shape
# Out:
# (426, 30)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.tree import plot_tree

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
def report(model, x, y, text='train'):
    print(f'{text}\t | \t {type(model).__name__}')
    print('-'*80)
    y_pred = model.predict(x)
    print(classification_report(y, y_pred))
    print('-'*80)
    print(pd.DataFrame(confusion_matrix(y, y_pred), index=['B', 'M'], columns=['B', 'M']))

# %%
def treePlot(model, feature_names, class_names):
    plot_tree(model, feature_names=feature_names, class_names=class_names, filled=True)
    plt.title(f'DecisionTreeClassifier with depth: {model.get_depth()}')
    plt.show()

# %%
model_default = DecisionTreeClassifier()

# %%
model_default.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
report(model_default, X_train, y_train)
# Out:
# train	 | 	 DecisionTreeClassifier
# --------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       267
#            1       1.00      1.00      1.00       159
#
#     accuracy                           1.00       426
#    macro avg       1.00      1.00      1.00       426
# weighted avg       1.00      1.00      1.00       426
#
# --------------------------------------------------------------------------------
#      B    M
# B  267    0
# M    0  159

# %%
report(model_default, X_test, y_test, 'test')
# Out:
# test	 | 	 DecisionTreeClassifier
# --------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95        90
#            1       0.89      0.94      0.92        53
#
#     accuracy                           0.94       143
#    macro avg       0.93      0.94      0.93       143
# weighted avg       0.94      0.94      0.94       143
#
# --------------------------------------------------------------------------------
#     B   M
# B  84   6
# M   3  50

# %%
treePlot(model_default, feature_names, ['B', 'M'])

# %%
model = DecisionTreeClassifier(max_depth=5, criterion='entropy', min_samples_split=25, random_state=123)

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_split=25,
#                        random_state=123)

# %%
report(model, X_train, y_train)
# Out:
# train	 | 	 DecisionTreeClassifier
# --------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       267
#            1       0.96      0.96      0.96       159
#
#     accuracy                           0.97       426
#    macro avg       0.97      0.97      0.97       426
# weighted avg       0.97      0.97      0.97       426
#
# --------------------------------------------------------------------------------
#      B    M
# B  260    7
# M    6  153

# %%
report(model, X_test, y_test, 'test')
# Out:
# test	 | 	 DecisionTreeClassifier
# --------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93        90
#            1       0.85      0.94      0.89        53
#
#     accuracy                           0.92       143
#    macro avg       0.91      0.92      0.91       143
# weighted avg       0.92      0.92      0.92       143
#
# --------------------------------------------------------------------------------
#     B   M
# B  81   9
# M   3  50

# %%
plt.figure(figsize=(30,30))
treePlot(model, feature_names, ['B', 'M'])

# %%
class_names = ['B', 'M']

# %%
from sklearn.model_selection import GridSearchCV

# %%
model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'entropy',
#  'max_depth': 5,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 25,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': 123,
#  'splitter': 'best'}

# %%
params = {
    'max_depth': [2,4,6,8,10,12,14],
    'criterion': ['gini', 'entropy']
}

# %%
estimator = GridSearchCV(DecisionTreeClassifier(), param_grid=params, cv=5, verbose=5)

# %%
estimator.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END .......criterion=gini, max_depth=2;, score=0.942 total time=   0.0s
# [CV 2/5] END .......criterion=gini, max_depth=2;, score=0.941 total time=   0.0s
# [CV 3/5] END .......criterion=gini, max_depth=2;, score=0.906 total time=   0.0s
# [CV 4/5] END .......criterion=gini, max_depth=2;, score=0.871 total time=   0.0s
# [CV 5/5] END .......criterion=gini, max_depth=2;, score=0.929 total time=   0.0s
# [CV 1/5] END .......criterion=gini, max_depth=4;, score=0.942 total time=   0.0s
# [CV 2/5] END .......criterion=gini, max_depth=4;, score=0.941 total time=   0.0s
# [CV 3/5] END .......criterion=gini, max_depth=4;, score=0.918 total time=   0.0s
# [CV 4/5] END .......criterion=gini, max_depth=4;, score=0.894 total time=   0.0s
# [CV 5/5] END .......criterion=gini, max_depth=4;, score=0.941 total time=   0.0s
# [CV 1/5] END .......criterion=gini, max_depth=6;, score=0.919 total time=   0.0s
# [CV 2/5] END .......criterion=gini, max_depth=6;, score=0.953 total time=   0.0s
# [CV 3/5] END .......criterion=gini, max_depth=6;, score=0.929 total time=   0.0s
# [CV 4/5] END .......criterion=gini, max_depth=6;, score=0.871 total time=   0.0s
# [CV 5/5] END .......criterion=gini, max_depth=6;, score=0.918 total time=   0.0s
# [CV 1/5] END .......criterion=gini, max_depth=8;, score=0.930 total time=   0.0s
# [CV 2/5] END .......criterion=gini, max_depth=8;, score=0.965 total time=   0.0s
# [CV 3/5] END .......criterion=gini, max_depth=8;, score=0.918 total time=   0.0s
# [CV 4/5] END .......criterion=gini, max_depth=8;, score=0.859 total time=   0.0s
# [CV 5/5] END .......criterion=gini, max_depth=8;, score=0.941 total time=   0.0s
# [CV 1/5] END ......criterion=gini, max_depth=10;, score=0.953 total time=   0.0s
# [CV 2/5] END ......criterion=gini, max_depth=10;, score=0.965 total time=   0.0s
# [CV 3/5] END ......criterion=gini, max_depth=10;, score=0.906 total time=   0.0s
# [CV 4/5] END ......criterion=gini, max_depth=10;, score=0.871 total time=   0.0s
# [CV 5/5] END ......criterion=gini, max_depth=10;, score=0.929 total time=   0.0s
# [CV 1/5] END ......criterion=gini, max_depth=12;, score=0.942 total time=   0.0s
# [CV 2/5] END ......criterion=gini, max_depth=12;, score=0.929 total time=   0.0s
# [CV 3/5] END ......criterion=gini, max_depth=12;, score=0.906 total time=   0.0s
# [CV 4/5] END ......criterion=gini, max_depth=12;, score=0.847 total time=   0.0s
# [CV 5/5] END ......criterion=gini, max_depth=12;, score=0.918 total time=   0.0s
# [CV 1/5] END ......criterion=gini, max_depth=14;, score=0.942 total time=   0.0s
# [CV 2/5] END ......criterion=gini, max_depth=14;, score=0.941 total time=   0.0s
# [CV 3/5] END ......criterion=gini, max_depth=14;, score=0.906 total time=   0.0s
# [CV 4/5] END ......criterion=gini, max_depth=14;, score=0.859 total time=   0.0s
# [CV 5/5] END ......criterion=gini, max_depth=14;, score=0.941 total time=   0.0s
# [CV 1/5] END ....criterion=entropy, max_depth=2;, score=0.942 total time=   0.0s
# [CV 2/5] END ....criterion=entropy, max_depth=2;, score=0.976 total time=   0.0s
# [CV 3/5] END ....criterion=entropy, max_depth=2;, score=0.906 total time=   0.0s
# [CV 4/5] END ....criterion=entropy, max_depth=2;, score=0.847 total time=   0.0s
# [CV 5/5] END ....criterion=entropy, max_depth=2;, score=0.882 total time=   0.0s
# [CV 1/5] END ....criterion=entropy, max_depth=4;, score=0.942 total time=   0.0s
# [CV 2/5] END ....criterion=entropy, max_depth=4;, score=0.976 total time=   0.0s
# [CV 3/5] END ....criterion=entropy, max_depth=4;, score=0.918 total time=   0.0s
# [CV 4/5] END ....criterion=entropy, max_depth=4;, score=0.882 total time=   0.0s
# [CV 5/5] END ....criterion=entropy, max_depth=4;, score=0.941 total time=   0.0s
# [CV 1/5] END ....criterion=entropy, max_depth=6;, score=0.942 total time=   0.0s
# [CV 2/5] END ....criterion=entropy, max_depth=6;, score=0.941 total time=   0.0s
# [CV 3/5] END ....criterion=entropy, max_depth=6;, score=0.918 total time=   0.0s
# [CV 4/5] END ....criterion=entropy, max_depth=6;, score=0.847 total time=   0.0s
# [CV 5/5] END ....criterion=entropy, max_depth=6;, score=0.941 total time=   0.0s
# [CV 1/5] END ....criterion=entropy, max_depth=8;, score=0.942 total time=   0.0s
# [CV 2/5] END ....criterion=entropy, max_depth=8;, score=0.941 total time=   0.0s
# [CV 3/5] END ....criterion=entropy, max_depth=8;, score=0.929 total time=   0.0s
# [CV 4/5] END ....criterion=entropy, max_depth=8;, score=0.847 total time=   0.0s
# [CV 5/5] END ....criterion=entropy, max_depth=8;, score=0.941 total time=   0.0s
# [CV 1/5] END ...criterion=entropy, max_depth=10;, score=0.942 total time=   0.0s
# [CV 2/5] END ...criterion=entropy, max_depth=10;, score=0.965 total time=   0.0s
# [CV 3/5] END ...criterion=entropy, max_depth=10;, score=0.906 total time=   0.0s
# [CV 4/5] END ...criterion=entropy, max_depth=10;, score=0.871 total time=   0.0s
# [CV 5/5] END ...criterion=entropy, max_depth=10;, score=0.953 total time=   0.0s
# [CV 1/5] END ...criterion=entropy, max_depth=12;, score=0.930 total time=   0.0s
# [CV 2/5] END ...criterion=entropy, max_depth=12;, score=0.953 total time=   0.0s
# [CV 3/5] END ...criterion=entropy, max_depth=12;, score=0.906 total time=   0.0s
# [CV 4/5] END ...criterion=entropy, max_depth=12;, score=0.835 total time=   0.0s
# [CV 5/5] END ...criterion=entropy, max_depth=12;, score=0.941 total time=   0.0s
# [CV 1/5] END ...criterion=entropy, max_depth=14;, score=0.953 total time=   0.0s
# [CV 2/5] END ...criterion=entropy, max_depth=14;, score=0.953 total time=   0.0s
# [CV 3/5] END ...criterion=entropy, max_depth=14;, score=0.941 total time=   0.0s
# [CV 4/5] END ...criterion=entropy, max_depth=14;, score=0.859 total time=   0.0s
# [CV 5/5] END ...criterion=entropy, max_depth=14;, score=0.953 total time=   0.0s
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 4, 6, 8, 10, 12, 14]},
#              verbose=5)

# %%
estimator.best_estimator_
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
model = estimator.best_estimator_

# %%
report(model, X_train, y_train)
# Out:
# train	 | 	 DecisionTreeClassifier
# --------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       267
#            1       0.99      0.96      0.98       159
#
#     accuracy                           0.98       426
#    macro avg       0.99      0.98      0.98       426
# weighted avg       0.98      0.98      0.98       426
#
# --------------------------------------------------------------------------------
#      B    M
# B  266    1
# M    6  153

# %%
report(model, X_test, y_test, 'test')
# Out:
# test	 | 	 DecisionTreeClassifier
# --------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95        90
#            1       0.88      0.96      0.92        53
#
#     accuracy                           0.94       143
#    macro avg       0.93      0.94      0.93       143
# weighted avg       0.94      0.94      0.94       143
#
# --------------------------------------------------------------------------------
#     B   M
# B  83   7
# M   2  51

# %%
plt.figure(figsize=(30,30))
treePlot(model, feature_names, class_names)
